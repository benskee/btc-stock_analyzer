# %% [markdown]
# <h1>Plan B</h1>

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# %% [markdown]
# <strong>Choose a Stock By Ticker Name</strong>

# %%
stock = 'SAVE'
start_date = '01-01-2020'
end_date = '08-03-2020'

# %% [markdown]
# <strong>Choose a Start Date (earliest date: 05-03-2019)</strong>
# (format mm-dd-yyyy)

# %%
start_date = '05-03-2020'

# %% [markdown]
# <strong>Choose an End Date (latest date: 08-03-2019)</strong>
# (format mm-dd-yyyy)

# %%
end_date = '07-03-2020'

# %% [markdown]
# <hr>

# %%
df_stock = pd.read_csv(f'{stock}.csv')
len(df_stock)
# Out:
# 23

# %%
df_stock
# Out:
#           Date  Close/Last    Volume     Open       High        Low
# 0   08/06/2020      $17.26  10967270    $17.3   $17.6499   $16.8387
# 1   08/05/2020      $17.15  16143430   $16.95     $17.52      $16.4
# 2   08/04/2020       $16.5  15034920   $15.46     $16.94     $15.45
# 3   08/03/2020      $15.37  15842450   $15.74      $15.8     $14.65
# 4   07/31/2020      $15.81  11920470   $16.04    $16.265     $15.42
# 5   07/30/2020      $16.24   8206604    $16.1     $16.38     $15.94
# 6   07/29/2020      $16.45   8039296   $16.56     $16.72   $16.1301
# 7   07/28/2020      $16.54  10390070   $16.07     $16.97     $16.06
# 8   07/27/2020      $16.15  11741090   $16.49     $16.84     $16.01
# 9   07/24/2020      $16.47  12735360   $16.81     $16.81     $16.16
# 10  07/23/2020      $16.84  25061640   $16.51     $17.82    $15.925
# 11  07/22/2020      $16.66   9376479   $16.54     $17.25   $16.4866
# 12  07/21/2020      $16.65  12062430    $16.9   $17.1934     $16.54
# 13  07/20/2020      $16.65  10734750   $17.61     $17.88     $16.61
# 14  07/17/2020      $17.61  10432140      $18    $18.388    $17.575
# 15  07/16/2020      $18.06  14308800    $18.2   $18.6634     $17.78
# 16  07/15/2020      $19.36  25489810   $18.27      $19.5     $18.03
# 17  07/14/2020      $17.27  11869510   $16.34      $17.3     $16.03
# 18  07/13/2020      $16.72  17931130   $17.58     $17.82     $16.47
# 19  07/10/2020      $17.53  20584910    $15.8     $17.64     $15.66
# 20  07/09/2020      $15.91  13143120   $16.54     $16.65     $15.54
# 21  07/08/2020      $16.71  14589560   $16.26   $16.8385     $15.85
# 22  07/07/2020      $16.77  10971730   $17.11     $17.28     $16.77

# %%
df_btc = pd.read_csv('btc.csv')
len(df_btc)
# Out:
# 448

# %%
df_btc.rename(columns=lambda x: x.replace(' ', '').lower(), inplace=True)
df_btc.columns
# Out:
# Index(['date', 'close/last', 'volume', 'open', 'high', 'low'], dtype='object')

# %%
for date in range(len(df_stock.Date)):
    df_stock.Date[date] = datetime.strptime(df_stock.Date[date], '%m/%d/%Y').date()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
start_date = datetime.strptime(start_date, '%m-%d-%Y').date()
end_date = datetime.strptime(end_date, '%m-%d-%Y').date()
start_date
# Out:
# datetime.date(2020, 5, 3)

# %%
for date in range(len(df_btc.date)):
    df_btc.date[date] = datetime.strptime(df_btc.date[date], '%m/%d/%Y').date()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_btc = df_btc.query('date > @start_date' )
df_btc = df_btc.query('date < @end_date' )
df_btc
# Out:
#           date  close/last volume     open     high      low
# 32  2020-07-02      9202.0    N/A   9150.6   9259.7   9179.5
# 33  2020-07-01      9233.4    N/A   9134.9   9259.7   9225.2
# 34  2020-06-30      9124.2    N/A   9166.4   9148.0   9101.1
# 35  2020-06-29      9171.7    N/A   9101.3   9199.8   9158.7
# 36  2020-06-28      9104.5    N/A   8971.0   9148.6   9097.1
# 37  2020-06-27      8970.6    N/A   9161.7   9008.2   8950.2
# 38  2020-06-26      9163.1    N/A   9245.1   9179.8   9113.9
# 39  2020-06-25      9249.4    N/A   9098.7   9296.5   9194.3
# 40  2020-06-24      9074.7    N/A   9649.9   9306.0   9022.6
# 41  2020-06-23      9645.9    N/A   9655.5   9663.7   9614.8
# 42  2020-06-22      9651.7    N/A   9383.5   9715.6   9609.3
# 43  2020-06-21      9378.5    N/A   9371.1   9395.2   9285.8
# 44  2020-06-20      9362.0    N/A   9332.0   9397.7   9349.1
# 45  2020-06-19      9331.8    N/A   9280.8   9350.1   9294.2
# 46  2020-06-18      9267.9    N/A   9428.9   9390.3   9249.6
# 47  2020-06-17      9436.3    N/A   9461.9   9468.8   9403.4
# 48  2020-06-16      9461.8    N/A   9558.0   9532.3   9423.8
# 49  2020-06-15      9549.2    N/A   9166.7   9570.7   9379.3
# 50  2020-06-14      9438.5    N/A   9419.3   9474.7   9387.5
# 51  2020-06-13      9431.5    N/A   9411.4   9474.7   9428.7
# 52  2020-06-12      9421.4    N/A   9365.1   9475.8   9415.5
# 53  2020-06-11      9381.5    N/A   9887.3   9391.3   9249.4
# 54  2020-06-10      9878.7    N/A   9753.7   9945.2   9871.0
# 55  2020-06-09      9754.2    N/A   9679.4   9805.8   9745.0
# 56  2020-06-08      9682.9    N/A   9724.4   9857.2   9616.6
# 57  2020-06-07      9718.6    N/A   9689.0   9770.5   9708.5
# 58  2020-06-06      9697.6    N/A   9631.3   9701.9   9637.3
# 59  2020-06-05      9616.2    N/A   9794.5   9629.3   9549.5
# 60  2020-06-04      9555.0    N/A   9527.4   9686.1   9537.6
# 61  2020-06-03      9681.7    N/A   9494.1   9686.1   9617.6
# 62  2020-06-02      9496.0    N/A  10093.9   9538.1   9483.4
# 63  2020-06-01     10080.8    N/A   9552.8  10207.3  10050.4
# 64  2020-05-31      9554.4    N/A   9533.1   9695.6   9529.8
# 65  2020-05-30      9587.2    N/A   9394.5   9695.6   9567.5
# 66  2020-05-29      9380.9    N/A   9519.9   9428.5   9352.7
# 67  2020-05-28      9525.3    N/A   9173.1   9596.5   9468.1
# 68  2020-05-27      9170.4    N/A   8831.8   9268.8   9168.8
# 69  2020-05-26      8850.5    N/A   8901.8   8891.0   8818.6
# 70  2020-05-25      8918.6    N/A   8786.4   8922.9   8836.6
# 71  2020-05-24      8773.7    N/A   9195.4   8817.9   8666.1
# 72  2020-05-23      9201.0    N/A   9284.2   9229.5   9129.7
# 73  2020-05-22      9275.5    N/A   8995.1   9303.2   9169.7
# 74  2020-05-21      8998.3    N/A   9479.3   9129.2   8983.7
# 75  2020-05-20      9477.8    N/A   9721.8   9567.1   9463.1
# 76  2020-05-19      9722.1    N/A   9537.9   9788.8   9708.4
# 77  2020-05-18      9524.6    N/A   9856.6   9737.8   9524.6
# 78  2020-05-17      9856.5    N/A   9543.2   9930.2   9678.9
# 79  2020-05-16      9559.1    N/A   9411.1   9570.4   9327.8
# 80  2020-05-15      9419.9    N/A   9483.6   9451.9   9233.0
# 81  2020-05-14      9497.4    N/A   9338.5   9819.6   9319.3
# 82  2020-05-13      9329.9    N/A   8908.7   9364.5   9265.8
# 83  2020-05-12      8913.3    N/A   8717.0   8964.7   8799.1
# 84  2020-05-11      8727.8    N/A   8697.6   8729.7   8542.8
# 85  2020-05-10      8659.3    N/A   9753.0   9569.4   8259.3
# 86  2020-05-09      8635.1    N/A   9868.2   9569.4   8259.3
# 87  2020-05-08      9873.7    N/A   9914.8   9910.5   9747.2
# 88  2020-05-07      9925.1    N/A   9271.8  10018.2   9845.8
# 89  2020-05-06      9263.6    N/A   8962.9   9338.2   9064.8
# 90  2020-05-05      8995.9    N/A   8855.8   9038.2   8923.6
# 91  2020-05-04      8870.5    N/A   8728.4   8920.7   8831.4

# %%
for c in [' Close/Last', ' Open', ' High', ' Low']:
    df_stock[c] = df_stock[c].str.replace('$', '').astype(float)
df_stock.head(5)
# Out:
#          Date   Close/Last    Volume   Open     High      Low
# 0  2020-08-06        17.26  10967270  17.30  17.6499  16.8387
# 1  2020-08-05        17.15  16143430  16.95  17.5200  16.4000
# 2  2020-08-04        16.50  15034920  15.46  16.9400  15.4500
# 3  2020-08-03        15.37  15842450  15.74  15.8000  14.6500
# 4  2020-07-31        15.81  11920470  16.04  16.2650  15.4200

# %%
df_stock.rename(columns=lambda x: x.replace(' ', '').lower(), inplace=True)
df_stock.columns
# Out:
# Index(['date', 'close/last', 'volume', 'open', 'high', 'low'], dtype='object')

# %%
avg_list = []
for date in df_stock.index:
    avg = (df_stock.high[date] + df_stock.low[date])/2
    avg_list.append(avg)
avg_list[0:5]
# Out:
# [17.2443, 16.96, 16.195, 15.225000000000001, 15.842500000000001]

# %%
btc_list = []
for date in df_btc.index:
    avg = round(((df_btc.high[date] + df_btc.low[date])/2), 2)
    btc_list.append(avg)
btc_list[0:5]
# Out:
# [9219.6, 9242.45, 9124.55, 9179.25, 9122.85]

# %%
df_btc['btc_avg'] = btc_list
df_btc.head(5)
# Out:
#           date  close/last volume    open    high     low  btc_avg
# 32  2020-07-02      9202.0    N/A  9150.6  9259.7  9179.5  9219.60
# 33  2020-07-01      9233.4    N/A  9134.9  9259.7  9225.2  9242.45
# 34  2020-06-30      9124.2    N/A  9166.4  9148.0  9101.1  9124.55
# 35  2020-06-29      9171.7    N/A  9101.3  9199.8  9158.7  9179.25
# 36  2020-06-28      9104.5    N/A  8971.0  9148.6  9097.1  9122.85

# %%
df_stock['stock_avg'] = avg_list
df_stock.head(5)
# Out:
#          date  close/last    volume   open     high      low  stock_avg
# 0  2020-08-06       17.26  10967270  17.30  17.6499  16.8387    17.2443
# 1  2020-08-05       17.15  16143430  16.95  17.5200  16.4000    16.9600
# 2  2020-08-04       16.50  15034920  15.46  16.9400  15.4500    16.1950
# 3  2020-08-03       15.37  15842450  15.74  15.8000  14.6500    15.2250
# 4  2020-07-31       15.81  11920470  16.04  16.2650  15.4200    15.8425

# %%
df_stock.columns
# Out:
# Index(['date', 'close/last', 'volume', 'open', 'high', 'low', 'stock_avg'], dtype='object')

# %%
df_premium = df_btc.drop(columns=['close/last', 'volume', 'open', 'high', 'low'], axis=1, inplace=False)
df_premium
# Out:
#           date   btc_avg
# 32  2020-07-02   9219.60
# 33  2020-07-01   9242.45
# 34  2020-06-30   9124.55
# 35  2020-06-29   9179.25
# 36  2020-06-28   9122.85
# 37  2020-06-27   8979.20
# 38  2020-06-26   9146.85
# 39  2020-06-25   9245.40
# 40  2020-06-24   9164.30
# 41  2020-06-23   9639.25
# 42  2020-06-22   9662.45
# 43  2020-06-21   9340.50
# 44  2020-06-20   9373.40
# 45  2020-06-19   9322.15
# 46  2020-06-18   9319.95
# 47  2020-06-17   9436.10
# 48  2020-06-16   9478.05
# 49  2020-06-15   9475.00
# 50  2020-06-14   9431.10
# 51  2020-06-13   9451.70
# 52  2020-06-12   9445.65
# 53  2020-06-11   9320.35
# 54  2020-06-10   9908.10
# 55  2020-06-09   9775.40
# 56  2020-06-08   9736.90
# 57  2020-06-07   9739.50
# 58  2020-06-06   9669.60
# 59  2020-06-05   9589.40
# 60  2020-06-04   9611.85
# 61  2020-06-03   9651.85
# 62  2020-06-02   9510.75
# 63  2020-06-01  10128.85
# 64  2020-05-31   9612.70
# 65  2020-05-30   9631.55
# 66  2020-05-29   9390.60
# 67  2020-05-28   9532.30
# 68  2020-05-27   9218.80
# 69  2020-05-26   8854.80
# 70  2020-05-25   8879.75
# 71  2020-05-24   8742.00
# 72  2020-05-23   9179.60
# 73  2020-05-22   9236.45
# 74  2020-05-21   9056.45
# 75  2020-05-20   9515.10
# 76  2020-05-19   9748.60
# 77  2020-05-18   9631.20
# 78  2020-05-17   9804.55
# 79  2020-05-16   9449.10
# 80  2020-05-15   9342.45
# 81  2020-05-14   9569.45
# 82  2020-05-13   9315.15
# 83  2020-05-12   8881.90
# 84  2020-05-11   8636.25
# 85  2020-05-10   8914.35
# 86  2020-05-09   8914.35
# 87  2020-05-08   9828.85
# 88  2020-05-07   9932.00
# 89  2020-05-06   9201.50
# 90  2020-05-05   8980.90
# 91  2020-05-04   8876.05

# %%
df_premium.set_index("date", inplace=True)
df_premium.head(1)
# Out:
#             btc_avg
# date
# 2020-07-02   9219.6

# %%
df_stock.set_index("date", inplace=True)
df_stock.head(1)
# Out:
#             close/last    volume  open     high      low  stock_avg
# date
# 2020-08-06       17.26  10967270  17.3  17.6499  16.8387    17.2443

# %%
df_premium['stock_avg'] = df_stock['stock_avg']
df_premium = df_premium.reset_index()
df_premium.head(5)
# Out:
#          date  btc_avg  stock_avg
# 0  2020-07-02  9219.60        NaN
# 1  2020-07-01  9242.45        NaN
# 2  2020-06-30  9124.55        NaN
# 3  2020-06-29  9179.25        NaN
# 4  2020-06-28  9122.85        NaN

# %%
format(1/11315*3144*10000, '.2f')
# Out:
# '2778.61'

# %%
format(1/df_premium.btc_avg[0] * df_premium.stock_avg[0] * 10000, '.2f') # price in 10,000 sats
# Out:
# 'nan'

# %%
sats_price_list = []
for date in df_premium.index:
    if df_premium.stock_avg[date]:
        sats_price = float(format(1/df_premium.btc_avg[date] * df_premium.stock_avg[date] * 10000, '.2f'))
        sats_price_list.append(sats_price)

df_premium['sats_price'] = sats_price_list
df_premium.head(5)
# Out:
#          date  btc_avg  stock_avg  sats_price
# 0  2020-07-02  9219.60        NaN         NaN
# 1  2020-07-01  9242.45        NaN         NaN
# 2  2020-06-30  9124.55        NaN         NaN
# 3  2020-06-29  9179.25        NaN         NaN
# 4  2020-06-28  9122.85        NaN         NaN

# %%
type(df_premium.sats_price[1])
# Out:
# numpy.float64

# %%
new_df = df_premium.query('date > datetime.strptime("07-03-2020", "%m-%d-%Y").date()' )
new_df = new_df.query('date < datetime.strptime("07-28-2020", "%m-%d-%Y").date()' )
new_df
# Out:
# Empty DataFrame
# Columns: [date, btc_avg, stock_avg, sats_price]
# Index: []

# %%
df_premium.date[0] == '2020-08-03'
# Out:
# False

# %%
plt.subplots(figsize=(15, 12))
plt.grid(True)
plt.plot(df_premium.date, df_premium.sats_price.fillna(method='ffill'), color='orange')
plt.plot(df_premium.date, df_premium.stock_avg.fillna(method='ffill'), color='green')
plt.title('Daily Stock Price in Bitcoin', fontsize=18)
plt.ylabel('Price in Tens of Thousands of Sats | Dollars', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.savefig('image_1.png')
plt.legend(['Bitcoin', 'Dollars'], loc=2);

# %%
plt.subplots(figsize=(15, 12))
plt.grid(True)
plt.plot(df_premium.date, df_premium.btc_avg.fillna(method='ffill'), color='gray')
plt.title('Daily Price of Bitcoin', fontsize=18)
plt.ylabel('Price in Dollars', fontsize=16)
plt.xlabel('Date', fontsize=16);
# plt.savefig('image_1.png');
